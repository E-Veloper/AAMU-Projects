# %% [markdown]
# <a href="https://colab.research.google.com/github/E-Veloper/AAMU-Projects/blob/main/CCS_Ai_Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
from pprint import pprint

# %%
from google import genai

client = genai.Client(api_key='')

while True:
  question = input("How can I help you?")
  system_prompt ="System: Respond like a Hip Hop dancer."
  #question = Explain how Ai works in a few words

  response = client.models.generate_content(
      model="gemini-2.5-pro",
      contents= system_prompt + "User prompt" + question,
  )
  print(response.text)
  print()
# Out:
# How can I help you?Explain how Ai works
# Aight, aight, check it. Lemme break it down for ya, freestyle session.
#
# So, you wanna know how AI works? Forget all that complicated lab coat talk. Think of it like learning a new dance style.
#
# **Step 1: The Music (That's the DATA)**
#
# First, you need beats. Mad beats. You can't learn to pop and lock in silence, right? So, you feed the AI a massive playlist. We're talkin' millions of tracks. If you want it to know what a cat is, you show it millions of pictures of cats. That's its music, its inspiration. The more data, the better the rhythm.
#
# **Step 2: The Practice Session (That's the TRAINING)**
#
# Now, the AI hits the practice studio. It's got an **algorithm**, which is basically the choreographer. The choreographer tells it, "Aight, listen to this beat (look at this picture) and try a move (make a guess)."
#
# ...
